# %%
# 1. Create a dictionary
mof_data = {
    "name": "Li-MOF-74",
    "surface_area": 1234.5,
    "pore_size": 11.8,
    "CO2_uptake": 4.2
}

# 2. list temperatures
temperatures = [273, 298, 323, 348, 373]

# 3. loop temperatures
for temp in temperatures:
    if temp > 298:
        print(f"{temp} K is above 298 K (room temperature).")
    elif temp < 298:
        print(f"{temp} K is below 298 K (room temperature).")
    else:
        print(f"{temp} K is equal to 298 K (room temperature).")

# 4. function
def celsius_to_kelvin(celsius):
    return celsius + 273.15

celsius_values = [0, 25, 100, -196]

print("\nCelsius to Kelvin conversion:")
for temp_c in celsius_values:
    temp_k = celsius_to_kelvin(temp_c)
    print(f"{temp_c} °C = {temp_k:.2f} K")
# Out:
# 273 K is below 298 K (room temperature).
# 298 K is equal to 298 K (room temperature).
# 323 K is above 298 K (room temperature).
# 348 K is above 298 K (room temperature).
# 373 K is above 298 K (room temperature).
#
# Celsius to Kelvin conversion:
# 0 °C = 273.15 K
# 25 °C = 298.15 K
# 100 °C = 373.15 K
# -196 °C = 77.15 K
